# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
# ### A simple app
#
# In this notebook we build a very simple app that uses our exported model.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Note how we are not importing anything from our source code (we do not use any module from the ``src`` directory). This is because the exported model, differently from the model weights, is a standalone serialization of our model and therefore it does not need anything else. You can ship that file to anybody, and as long as they can import ``torch``, they will be able to use your model. This is very important for releasing pytorch models to production.
#
# ### Test your app
# Go to a search engine for images (like Google Images) and search for images of some of the landmarks, like the Eiffel Tower, the Golden Gate Bridge, Machu Picchu and so on. Save a few examples locally, then upload them to your app to see how your model behaves!
#
# The app will show the top 5 classes that the model think are most relevant for the picture you have uploaded

# %%
from ipywidgets import VBox, Button, FileUpload, Output, Label
from PIL import Image
from IPython.display import display
import io
import numpy as np
import torchvision
import torchvision.transforms as T
import torch

# Decide which model you want to use among the ones exported
learn_inf = torch.jit.load("checkpoints/transfer_exported.pt")

def on_click_classify(change):

    # Load image that has been uploaded
    fn = io.BytesIO(btn_upload.data[-1])

    img = Image.open(fn)
    img.load()

    # Let's clear the previous output (if any)
    out_pl.clear_output()

    # Display the image
    with out_pl:

        ratio = img.size[0] / img.size[1]
        c = img.copy()
        c.thumbnail([ratio * 200, 200])
        display(c)

    # Transform to tensor
    timg = T.ToTensor()(img).unsqueeze_(0)

    # Calling the model
    softmax = learn_inf(timg).data.cpu().numpy().squeeze()
    
    # Get the indexes of the classes ordered by softmax
    # (larger first)
    idxs = np.argsort(softmax)[::-1]
    
    # Loop over the classes with the largest softmax
    for i in range(5):
        # Get softmax value
        p = softmax[idxs[i]]
    
        # Get class name
        landmark_name = learn_inf.class_names[idxs[i]]
        
        labels[i].value = f"{landmark_name} (prob: {p:.2f})"


# Putting back btn_upload to a widget for next cell
btn_upload = FileUpload()

btn_run = Button(description="Classify")
btn_run.on_click(on_click_classify)

labels = []
for _ in range(5):
    labels.append(Label())

out_pl = Output()
out_pl.clear_output()

wgs = [Label("Please upload a picture of a landmark"), btn_upload, btn_run, out_pl]
wgs.extend(labels)

VBox(wgs)
# Out:
# VBox(children=(Label(value='Please upload a picture of a landmark'), FileUpload(value={}, description='Upload'…

# %% [markdown]
# ## (optional) Standalone app or web app
#
# You can run this notebook as a standalone app on your computer by following these steps:
#
# 1. Download this notebook in a directory on your machine
# 2. Download the model export (for example, ``checkpoints/transfer_exported.pt``) in a subdirectory called ``checkpoints`` within the directory where you save the app.ipynb notebook
# 3. Install voila if you don't have it already (``pip install voila``)
# 4. Run your app: ``voila app.ipynb --show_tracebacks=True``
# 5. Customize your notebook to make your app prettier and rerun voila
#
# You can also deploy this app as a website using Binder: https://voila.readthedocs.io/en/stable/deploy.html#deployment-on-binder

# %% [markdown]
# # Create your submission archive
#
# Now that you are done with your project, please run the following cell. It will generate a file containing all the code you have written, as well as the notebooks. Please submit that file to complete your project

# %%
# !pip install --upgrade jupyter nbconvert
# Out:
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: nbconvert in ./.conda/envs/default/lib/python3.9/site-packages (7.3.0)
# Collecting nbconvert
#   Using cached nbconvert-7.7.3-py3-none-any.whl (254 kB)
# Requirement already satisfied: ipywidgets in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter) (7.7.5)
# Requirement already satisfied: ipykernel in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter) (6.4.2)
# Collecting qtconsole
#   Using cached qtconsole-5.4.3-py3-none-any.whl (121 kB)
# Requirement already satisfied: notebook in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter) (6.5.3)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: defusedxml in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: packaging in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (23.0)
# Requirement already satisfied: jupyterlab-pygments in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (0.2.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (6.0.0)
# Requirement already satisfied: nbformat>=5.7 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (5.8.0)
# Requirement already satisfied: importlib-metadata>=3.6 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (6.1.0)
# Requirement already satisfied: jinja2>=3.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: jupyter-core>=4.7 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (5.3.0)
# Requirement already satisfied: pygments>=2.4.1 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (2.14.0)
# Requirement already satisfied: tinycss2 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (1.2.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (2.0.5)
# Requirement already satisfied: markupsafe>=2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (2.1.2)
# Requirement already satisfied: traitlets>=5.1 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (5.9.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (0.7.3)
# Requirement already satisfied: beautifulsoup4 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert) (4.12.0)
# Requirement already satisfied: webencodings in ./.conda/envs/default/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in ./.conda/envs/default/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in ./.conda/envs/default/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-core>=4.7->nbconvert) (3.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.conda/envs/default/lib/python3.9/site-packages (from nbclient>=0.5.0->nbconvert) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5.4 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.8.2)
# Requirement already satisfied: entrypoints in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (0.4)
# Requirement already satisfied: tornado>=6.2 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.2)
# Requirement already satisfied: pyzmq>=23.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (25.0.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.conda/envs/default/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert) (4.17.3)
# Requirement already satisfied: fastjsonschema in ./.conda/envs/default/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert) (2.16.3)
# Requirement already satisfied: attrs>=17.4.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.19.3)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/envs/default/lib/python3.9/site-packages (from beautifulsoup4->nbconvert) (2.3.2.post1)
# Requirement already satisfied: ipython-genutils in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter) (7.33.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter) (1.6.6)
# Requirement already satisfied: pexpect>4.3 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: decorator in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.18.2)
# Requirement already satisfied: backcall in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (67.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (3.0.38)
# Requirement already satisfied: pickleshare in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./.conda/envs/default/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in ./.conda/envs/default/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->jupyter) (0.2.6)
# Requirement already satisfied: widgetsnbextension~=3.6.4 in ./.conda/envs/default/lib/python3.9/site-packages (from ipywidgets->jupyter) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipywidgets->jupyter) (1.1.4)
# Requirement already satisfied: nbclassic>=0.4.7 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter) (0.5.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter) (0.17.1)
# Requirement already satisfied: argon2-cffi in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: prometheus-client in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter) (0.16.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in ./.conda/envs/default/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (2.5.0)
# Requirement already satisfied: websocket-client in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.5.1)
# Requirement already satisfied: jupyter-server-terminals in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.4.4)
# Requirement already satisfied: anyio>=3.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.6.3)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.3.0)
# Requirement already satisfied: rfc3339-validator in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.1.4)
# Requirement already satisfied: pyyaml>=5.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (6.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (2.0.7)
# Requirement already satisfied: isoduration in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (20.11.0)
# Requirement already satisfied: uri-template in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2.4)
# Requirement already satisfied: webcolors>=1.11 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (1.13)
# Requirement already satisfied: fqdn in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.conda/envs/default/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in ./.conda/envs/default/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in ./.conda/envs/default/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert) (1.2.3)
# Collecting ipykernel
#   Downloading ipykernel-6.25.1-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 11.9 MB/s eta 0:00:01
# Collecting comm>=0.1.1
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting psutil
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      |████████████████████████████████| 282 kB 82.1 MB/s eta 0:00:01
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.1-py3-none-any.whl (84 kB)
# Installing collected packages: nbconvert, psutil, comm, ipykernel, qtpy, qtconsole, jupyter-console, jupyter
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.3.0
#     Uninstalling nbconvert-7.3.0:
#       Successfully uninstalled nbconvert-7.3.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.4.2
#     Uninstalling ipykernel-6.4.2:
#       Successfully uninstalled ipykernel-6.4.2
# Successfully installed comm-0.1.4 ipykernel-6.25.1 jupyter-1.0.0 jupyter-console-6.6.3 nbconvert-7.7.3 psutil-5.9.5 qtconsole-5.4.3 qtpy-2.3.1

# %%
# !python src/create_submit_pkg.py
# Out:
# executing: jupyter nbconvert --to html app.ipynb
# [NbConvertApp] Converting notebook app.ipynb to html
# [NbConvertApp] Writing 304711 bytes to app.html
# executing: jupyter nbconvert --to html cnn_from_scratch.ipynb
# [NbConvertApp] Converting notebook cnn_from_scratch.ipynb to html
# Traceback (most recent call last):
#   File "/home/studio-lab-user/.conda/envs/default/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/jupyter_core/application.py", line 277, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 414, in start
#     self.convert_notebooks()
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 589, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 555, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 481, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 389, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 395, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/html.py", line 259, in from_notebook_node
#     html, resources = super().from_notebook_node(nb, resources, **kw)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 427, in from_notebook_node
#     output = self.template.render(nb=nb_copy, resources=resources)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/jinja2/environment.py", line 1301, in render
#     self.environment.handle_exception()
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/jinja2/environment.py", line 936, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/lab/index.html.j2", line 4, in top-level template code
#     {% from 'jupyter_widgets.html.j2' import jupyter_widgets %}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/lab/base.html.j2", line 3, in top-level template code
#     {% from 'cell_id_anchor.j2' import cell_id_anchor %}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/base/display_priority.j2", line 1, in top-level template code
#     {%- extends 'base/null.j2' -%}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/base/null.j2", line 26, in top-level template code
#     {%- block body -%}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/base/null.j2", line 29, in block 'body'
#     {%- block body_loop -%}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/base/null.j2", line 31, in block 'body_loop'
#     {%- block any_cell scoped -%}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/base/null.j2", line 87, in block 'any_cell'
#     {%- block markdowncell scoped-%} {%- endblock markdowncell -%}
#   File "/home/studio-lab-user/.conda/envs/default/share/jupyter/nbconvert/templates/lab/base.html.j2", line 109, in block 'markdowncell'
#     {%- set html_value=cell.source  | markdown2html | strip_files_prefix -%}
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/exporters/html.py", line 236, in markdown2html
#     return MarkdownWithMath(renderer=renderer).render(source)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/filters/markdown_mistune.py", line 486, in render
#     return str(super().__call__(source))
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/markdown.py", line 65, in __call__
#     return self.parse(s)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/markdown.py", line 50, in parse
#     result = self.block.render(tokens, self.inline, state)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/block_parser.py", line 274, in render
#     return inline.renderer.finalize(data)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/renderers.py", line 220, in finalize
#     return ''.join(data)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/block_parser.py", line 284, in _iter_render
#     children = self.render(tok['children'], inline, state)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/block_parser.py", line 274, in render
#     return inline.renderer.finalize(data)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/renderers.py", line 220, in finalize
#     return ''.join(data)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/mistune/block_parser.py", line 291, in _iter_render
#     yield method(children, *params)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/nbconvert/filters/markdown_mistune.py", line 302, in block_code
#     lang = info.strip().split(maxsplit=1)[0]
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "/home/studio-lab-user/src/create_submit_pkg.py", line 40, in <module>
#     create_submit_pkg()
#   File "/home/studio-lab-user/src/create_submit_pkg.py", line 20, in create_submit_pkg
#     subprocess.check_call(cmd_line, shell=True)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/subprocess.py", line 373, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command 'jupyter nbconvert --to html cnn_from_scratch.ipynb' returned non-zero exit status 1.
